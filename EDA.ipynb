# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_amazon.csv')
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.head()
# Out:
#   current_date  highest_price highest_date  lowest_price lowest_date  \
# 0          Oct          49.99          Sep         34.99         Oct
# 1          Oct          39.99          Aug         24.99         Oct
# 2          Oct          49.99          Oct         24.99         Aug
# 3          Feb          24.99          Feb         19.99         Feb
# 4          Oct          49.99          Oct         24.99         Aug
#
#          asin     category                                               name  \
# 0  B079QHML21  Electronics  Fire TV Stick 4K with Alexa Voice Remote, stre...
# 1  B0791TX5P5  Electronics  Fire TV Stick with Alexa Voice Remote, streami...
# 2  B07FZ8S74R  Electronics  Echo Dot (3rd Gen) - Smart speaker with Alexa ...
# 3  B01MZEEFNX  Electronics  Amazon Smart Plug, works with Alexa – A Certif...
# 4  B07PGL2N7J  Electronics  Echo Dot (3rd Gen) - Smart speaker with Alexa ...
#
#    num_reviews  price  product_id  rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 13 columns):
# current_date     373 non-null object
# highest_price    373 non-null float64
# highest_date     373 non-null object
# lowest_price     373 non-null float64
# lowest_date      373 non-null object
# asin             373 non-null object
# category         373 non-null object
# name             373 non-null object
# num_reviews      373 non-null int64
# price            369 non-null float64
# product_id       373 non-null object
# rating           373 non-null float64
# url              373 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 38.0+ KB

# %%
df.describe()
# Out:
#        highest_price  lowest_price    num_reviews       price      rating
# count     373.000000    373.000000     373.000000  369.000000  373.000000
# mean       49.459062     28.643619    6314.050938   37.893469    4.281501
# std        78.556627     47.680727   15284.748178   62.074954    0.304899
# min         4.990000      0.420000       1.000000    0.790000    3.300000
# 25%        14.990000      5.590000     843.000000    9.640000    4.100000
# 50%        25.280000     12.990000    1935.000000   17.890000    4.300000
# 75%        49.990000     29.690000    4219.000000   37.980000    4.500000
# max       999.990000    497.990000  137391.000000  697.990000    4.800000

# %%
df.hist(figsize=(30,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a26b6cfd0>,
# ...
#       dtype=object)

# %%
sns.scatterplot(df['num_reviews'],df['lowest_price'])

# %%
sns.scatterplot(df['rating'],df['lowest_price'])

# %%
sns.scatterplot(df['lowest_date'],df['lowest_price'])

# %%
sns.scatterplot(df['price'],df['lowest_price'])
